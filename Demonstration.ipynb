# %%
# %cd /content/drive/MyDrive/Colab Notebooks/-Intelligent_Placer
# Out:
# /content/drive/MyDrive/Colab Notebooks/-Intelligent_Placer

# %%
image ,  fill_hole_ima = findPolyGon_Object("./Input/6True.jpg")
print("First photo: Input 6True.jpg\nSecond photo : Use method Canna find border \nThird photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)")
print("Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h ")
bool_Check = CheckPolygon_Object(image ,  fill_hole_ima)
print("Check if the maximum size is the size of the image : If false returns false \n If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true. ")
print("We have result:" , bool_Check)
# Out:
# First photo: Input 1false.jpg
# Second photo : Use method Canna find border
# Third photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)
# Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h
# 163 383 94 171
# 186 218 51 51
# remove the edges by removing the shapes with an area less than 5 we get the size of the object and the shape (in the correct order: last image):
# 94 171
# 51 51
# Check if the maximum size is the size of the image : If false returns false
#  If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true.
# We have result: True

# %%
image ,  fill_hole_ima = findPolyGon_Object("./Input/12false.jpg")
print("First photo: Input 12false.jpg\nSecond photo : Use method Canna find border \nThird photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)")
print("Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h ")
bool_Check = CheckPolygon_Object(image ,  fill_hole_ima)
print("Check if the maximum size is the size of the image : If false returns false \n If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true. ")
print("We have result: ",bool_Check ,"because (215 < 136 + 154 and 155 < 88+118) ")
# Out:
# First photo: Input 1false.jpg
# Second photo : Use method Canna find border
# Third photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)
# Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h
# 97 375 215 155
# 0 212 136 88
# 181 182 154 118
# remove the edges by removing the shapes with an area less than 5 we get the size of the object and the shape (in the correct order: last image):
# 215 155
# 136 88
# 154 118
# Check if the maximum size is the size of the image : If false returns false
#  If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true.
# We have result:  False because (215 < 136 + 154 and 155 < 88+118)

# %%
image ,  fill_hole_ima = findPolyGon_Object("./Input/9false.jpg")
print("First photo: Input 9false.jpg\nSecond photo : Use method Canna find border \nThird photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)")
print("Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h ")
bool_Check = CheckPolygon_Object(image ,  fill_hole_ima)
print("Check if the maximum size is the size of the image : If false returns false \n If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true. ")
print("We have result: ",bool_Check ,"because 202 > 170 ")
# Out:
# First photo: Input 9false.jpg
# Second photo : Use method Canna find border
# Third photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)
# Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h
# 160 385 92 170
# 84 86 207 188
# remove the edges by removing the shapes with an area less than 5 we get the size of the object and the shape (in the correct order: last image):
# 92 170
# 207 188
# Check if the maximum size is the size of the image : If false returns false
#  If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true.
# We have result:  False because 202 > 170

# %%
image ,  fill_hole_ima = findPolyGon_Object("./Input/7True.jpg")
print("First photo: Input 7True.jpg\nSecond photo : Use method Canna find border \nThird photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)")
print("Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h ")
bool_Check = CheckPolygon_Object(image ,  fill_hole_ima)
print("Check if the maximum size is the size of the image : If false returns false \n If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true. ")
print("We have result: ",bool_Check )
# Out:
# First photo: Input 7True.jpg
# Second photo : Use method Canna find border
# Third photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)
# Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h
# 70 301 329 276
# 127 110 156 125
# remove the edges by removing the shapes with an area less than 5 we get the size of the object and the shape (in the correct order: last image):
# 329 276
# 156 125
# Check if the maximum size is the size of the image : If false returns false
#  If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true.
# We have result:  True

# %%
image ,  fill_hole_ima = findPolyGon_Object("./Input/14True.jpg")
print("First photo: Input 14True.jpg\nSecond photo : Use method Canna find border \nThird photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)")
print("Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h ")
bool_Check = CheckPolygon_Object(image ,  fill_hole_ima)
print("Check if the maximum size is the size of the image : If false returns false \n If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true. ")
print("We have result: ",bool_Check )
# Out:
# First photo: Input 14True.jpg
# Second photo : Use method Canna find border
# Third photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)
# Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h
# 52 304 316 251
# 99 36 221 227
# remove the edges by removing the shapes with an area less than 5 we get the size of the object and the shape (in the correct order: last image):
# 316 251
# 221 227
# Check if the maximum size is the size of the image : If false returns false
#  If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true.
# We have result:  True

# %%
image ,  fill_hole_ima = findPolyGon_Object("./Input/1false.jpg")
print("First photo: Input 1false.jpg\nSecond photo : Use method Canna find border \nThird photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)")
print("Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h ")
bool_Check = CheckPolygon_Object(image ,  fill_hole_ima)
print("Check if the maximum size is the size of the image : If false returns false \n If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true. ")
print("We have result: ",bool_Check )
# Out:
# First photo: Input 14True.jpg
# Second photo : Use method Canna find border
# Third photo : use method fill hole to identify objects and shapes with full color (only the other colored objects and shapes are ignored)
# Get coordinates of shapes obtained after filling with fill hole : x , y ,w, h
# 166 301 160 107
# 122 72 183 97
# remove the edges by removing the shapes with an area less than 5 we get the size of the object and the shape (in the correct order: last image):
# 160 107
# 183 97
# Check if the maximum size is the size of the image : If false returns false
#  If true, we also have to check if any side of the shape is greater than the sum of all edges of the envelope, if no edges return false, otherwise true.
# We have result:  False

# %%
import os
import matplotlib.pyplot as plt
from pathlib import Path
import cv2
import numpy as np
import glob
import os

# %%
def FixSize(img):
    coefficient = 30/100
    width = int(img.shape[1] * coefficient)
    height = int(img.shape[0] * coefficient)
    dim = (width, height)
    newImg = cv2.resize(img, dim)
  
    return newImg

# %%
def floorFill(imgThick):
        imgFloodFill = imgThick.copy()
        h, w = imgThick.shape[:2]
        mask = np.zeros((h + 2, w + 2), np.uint8)
        startPoint = (0, 0)
        cv2.floodFill(imgFloodFill, mask, startPoint, 255)
        imgPolygon = cv2.bitwise_not(imgFloodFill)
        
        return imgPolygon

# %%
def FixEdge(img):
        kernel = np.ones((5, 5), np.uint8)
        imgNew = cv2.dilate(img, kernel, iterations=1)
        return imgNew

# %%
def fillhole(input_image):
    '''
    input gray binary image  get the filled image by floodfill method
    Note: only holes surrounded in the connected regions will be filled.
    :param input_image:
    :return:
    '''
    im_flood_fill = input_image.copy()
    h, w = input_image.shape[:2]
    mask = np.zeros((h + 2, w + 2), np.uint8)
    im_flood_fill = im_flood_fill.astype("uint8")
    cv2.floodFill(im_flood_fill, mask, (0, 0), 255)
    im_flood_fill_inv = cv2.bitwise_not(im_flood_fill)
    img_out = input_image | im_flood_fill_inv
    
    return img_out

# %%
def findPolyGon_Object(nameImage):
    image1 = cv2.imread(nameImage)
    image = FixSize(image1)

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (3,3), 0)
    canny = cv2.Canny(blurred, 120, 200, 1)
    canny_New = FixEdge(canny)
    fill_hole_ima = fillhole(canny_New)
    f, ax = plt.subplots(1, 3, figsize=(10, 10))
    ax[0].set_title(f"Input")
    ax[1].set_title(f"Method Canna")
    ax[2].set_title(f"Fill hole")
    ax[0].imshow(image,cmap="gray")
    ax[1].imshow(canny,cmap="gray")
    ax[2].imshow(fill_hole_ima,cmap="gray")  
    #plt.savefig(f"output/result_{os.path.basename(nameImage)}")
    #plt.close()
    return image , fill_hole_ima

# %%
def CheckPolygon_Object(image ,  fill_hole_ima):
    # tìm toạ độ các đường viền
    contours, hierarchy = cv2.findContours(fill_hole_ima, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    

    img2 = image.copy()
    index = 0
    areas_orig = []
    areas_bboxes = []
    all_width = []
    all_height =[]
    ymax = 0
    for i,contour in enumerate(contours):
        
        # lấy toạ độ các vật thể với xleft, ytop, width,height
        x,y,w,h = cv2.boundingRect(contour)
        print( x,y,w,h)
        # loại bỏ các viền có diện tích nhở hơn 5 
        if cv2.contourArea(contour)<5:
            continue
        # lấy toàn bộ kích thước của các vật thể và hình
        all_width.append(w)
        all_height.append(h)
        # tìm toạ độ của hình
        if ymax == 0:
            ymax = y
        else:
            if y>ymax:
               ymax = y
               index = i
            
    
    all_width = np.array(all_width)
    all_height =np.array(all_height)
    print("remove the edges by removing the shapes with an area less than 5 we get the size of the object and the shape (in the correct order: last image):")
    for i in range(len(all_width)):
      print(all_width[i] , all_height[i])
    # tìm vật thể có kích thước lớn nhất
    width_max = np.argmax(all_width)
    height_max = np.argmax(all_height)
    # tìm vật thể có diện tích lớn nhất
    '''areas_figure = areas_orig[index]
    areas_bboxes = np.array(areas_bboxes)
    areas_bboxes[index] = areas_figure
    area_max = np.argmax(areas_bboxes)'''
    
# kiểm tra xem vật thể có  kích thước lớn nhất đó có phải là hình hay không
# đúng thì vật thể nằm, còn sai thì vật thể nằm ngoài
    if (width_max == index and height_max == index):#area_max==index and 
        if((2 *max(all_width) < sum(all_width)) and (2 * max(all_height) < sum(all_height))):
            return False
        else:
          return True
    else:
        return False
